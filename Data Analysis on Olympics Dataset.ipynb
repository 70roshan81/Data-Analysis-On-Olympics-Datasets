# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load Dataset
athletes = pd.read_csv('C:/Users/ROSHAN/OneDrive/Documents/Athletes_summer_games.csv')
region = pd.read_csv('C:/Users/ROSHAN/OneDrive/Documents/regions.csv')

# %%
athletes.head()
# Out:
#    ID                                Name Sex   Age            Team  NOC  \
# 0   0                           A Dijiang   M  24.0           China  CHN
# 1   1                            A Lamusi   M  23.0           China  CHN
# 2   2                 Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3   3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4  26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
#
#          Games  Year  Season         City       Sport  \
# 0  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  2012 Summer  2012  Summer       London        Judo
# 2  1920 Summer  1920  Summer    Antwerpen    Football
# 3  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN
# 3   Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
region.head()
# Out:
#    Unnamed: 0  NOC       region notes
# 0           0  EOR      Refugee   NaN
# 1           1  LBN      Lebanon   NaN
# 2           2  SGP    Singapore   NaN
# 3           3  ROC       Russia   NaN
# 4           4  AFG  Afghanistan   NaN

# %%
# Join the dataframe

athletes_df = athletes.merge(region, how = 'left', on='NOC')
athletes_df.head()
# Out:
#    ID                                Name Sex   Age            Team  NOC  \
# 0   0                           A Dijiang   M  24.0           China  CHN
# 1   1                            A Lamusi   M  23.0           China  CHN
# 2   2                 Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3   3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4  26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
#
#          Games  Year  Season         City       Sport  \
# 0  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  2012 Summer  2012  Summer       London        Judo
# 2  1920 Summer  1920  Summer    Antwerpen    Football
# 3  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal  Unnamed: 0       region notes
# 0   Basketball Men's Basketball   NaN          45        China   NaN
# ...

# %%
athletes_df.shape
# Out:
# (237673, 16)

# %%
athletes_df.rename(columns = {'region':'Region','notes':'Notes'},inplace = True)

# %%
athletes_df.head()
# Out:
#    ID                                Name Sex   Age            Team  NOC  \
# 0   0                           A Dijiang   M  24.0           China  CHN
# 1   1                            A Lamusi   M  23.0           China  CHN
# 2   2                 Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3   3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4  26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
#
#          Games  Year  Season         City       Sport  \
# 0  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  2012 Summer  2012  Summer       London        Judo
# 2  1920 Summer  1920  Summer    Antwerpen    Football
# 3  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal  Unnamed: 0       Region Notes
# 0   Basketball Men's Basketball   NaN          45        China   NaN
# ...

# %%
athletes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237673 entries, 0 to 237672
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          237673 non-null  int64
#  1   Name        237673 non-null  object
#  2   Sex         237673 non-null  object
#  3   Age         228484 non-null  float64
#  4   Team        237673 non-null  object
#  5   NOC         237673 non-null  object
#  6   Games       237673 non-null  object
#  7   Year        237673 non-null  int64
#  8   Season      237673 non-null  object
#  9   City        237673 non-null  object
#  10  Sport       237673 non-null  object
#  11  Event       237673 non-null  object
#  12  Medal       36537 non-null   object
#  13  Unnamed: 0  237673 non-null  int64
#  14  Region      237650 non-null  object
#  15  Notes       4525 non-null    object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 30.8+ MB

# %%
athletes_df.describe()
# Out:
#                   ID            Age           Year     Unnamed: 0
# count  237673.000000  228484.000000  237673.000000  237673.000000
# mean   126947.990521      25.746267    1979.096246     112.653284
# std     82093.460104       6.638720      31.783967      65.638110
# min         0.000000      10.000000    1896.000000       0.000000
# 25%     52693.000000      21.000000    1960.000000      67.000000
# 50%    126221.000000      25.000000    1988.000000      98.000000
# 75%    198214.000000      29.000000    2004.000000     173.000000
# max    271110.000000      97.000000    2020.000000     233.000000

# %%
# Check Null

nan_values = athletes_df.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID            False
# Name          False
# Sex           False
# Age            True
# Team          False
# NOC           False
# Games         False
# Year          False
# Season        False
# City          False
# Sport         False
# Event         False
# Medal          True
# Unnamed: 0    False
# Region         True
# Notes          True
# dtype: bool

# %%
athletes_df.isnull().sum()
# Out:
# ID                 0
# Name               0
# Sex                0
# Age             9189
# Team               0
# NOC                0
# Games              0
# Year               0
# Season             0
# City               0
# Sport              0
# Event              0
# Medal         201136
# Unnamed: 0         0
# Region            23
# Notes         233148
# dtype: int64

# %%
#Print the columns name containing the Null and missing values in the list.

athletes_df.columns[athletes_df.isnull().any()].tolist()
# Out:
# ['Age', 'Medal', 'Region', 'Notes']

# %%
#Print the columns name containing the Null and missing values without list

athletes_df.columns[athletes_df.isnull().any()]
# Out:
# Index(['Age', 'Medal', 'Region', 'Notes'], dtype='object')

# %%
# India Details

athletes_df.query('Team == "India"')
# Out:
#            ID                             Name Sex   Age   Team  NOC  \
# 436       505                   S. Abdul Hamid   M   NaN  India  IND
# 437       506                   S. Abdul Hamid   M   NaN  India  IND
# 790       895  Shiny Kurisingal Abraham-Wilson   F  19.0  India  IND
# 791       896  Shiny Kurisingal Abraham-Wilson   F  19.0  India  IND
# 792       897  Shiny Kurisingal Abraham-Wilson   F  23.0  India  IND
# ...       ...                              ...  ..   ...    ...  ...
# 236448  13896                   VERMA Abhishek   M  32.0  India  IND
# 236449  13897                   VERMA Abhishek   M  32.0  India  IND
# 236523  13971                    VINESH Vinesh   F  26.0  India  IND
# 237183  14631             YAHIYA Muhammed Anas   M  26.0  India  IND
# 237184  14632             YAHIYA Muhammed Anas   M  26.0  India  IND
#
#               Games  Year  Season         City      Sport  \
# 436     1928 Summer  1928  Summer    Amsterdam  Athletics
# ...

# %%
# India Details

athletes_df.query('Team == "India"').head()
# Out:
#       ID                             Name Sex   Age   Team  NOC        Games  \
# 436  505                   S. Abdul Hamid   M   NaN  India  IND  1928 Summer
# 437  506                   S. Abdul Hamid   M   NaN  India  IND  1928 Summer
# 790  895  Shiny Kurisingal Abraham-Wilson   F  19.0  India  IND  1984 Summer
# 791  896  Shiny Kurisingal Abraham-Wilson   F  19.0  India  IND  1984 Summer
# 792  897  Shiny Kurisingal Abraham-Wilson   F  23.0  India  IND  1988 Summer
#
#      Year  Season         City      Sport  \
# 436  1928  Summer    Amsterdam  Athletics
# 437  1928  Summer    Amsterdam  Athletics
# 790  1984  Summer  Los Angeles  Athletics
# 791  1984  Summer  Los Angeles  Athletics
# 792  1988  Summer        Seoul  Athletics
#
#                                       Event Medal  Unnamed: 0 Region Notes
# 436      Athletics Men's 110 metres Hurdles   NaN          96  India   NaN
# 437      Athletics Men's 400 metres Hurdles   NaN          96  India   NaN
# ...

# %%
# Japan Details

athletes_df.query('Team == "Japan"').head()
# Out:
#       ID         Name Sex   Age   Team  NOC        Games  Year  Season  \
# 556  625  Isao Ko Abe   M  24.0  Japan  JPN  1936 Summer  1936  Summer
# 557  630    Kazuo Abe   M  25.0  Japan  JPN  1960 Summer  1960  Summer
# 558  631    Kinya Abe   M  23.0  Japan  JPN  1992 Summer  1992  Summer
# 559  632  Kiyoshi Abe   M  25.0  Japan  JPN  1972 Summer  1972  Summer
# 560  638    Naoki Abe   M  23.0  Japan  JPN  1968 Summer  1968  Summer
#
#             City      Sport                                     Event Medal  \
# 556       Berlin  Athletics              Athletics Men's Hammer Throw   NaN
# 557         Roma  Wrestling    Wrestling Men's Lightweight, Freestyle   NaN
# 558    Barcelona    Fencing            Fencing Men's Foil, Individual   NaN
# 559       Munich  Wrestling  Wrestling Men's Featherweight, Freestyle   NaN
# 560  Mexico City  Athletics      Athletics Men's 4 x 100 metres Relay   NaN
#
#      Unnamed: 0 Region Notes
# 556         108  Japan   NaN
# ...

# %%
# Top 10 countries Participating 

top_10_countries = athletes_df.Team.value_counts().sort_values(ascending=False).head(10)
top_10_countries
# Out:
# United States    15382
# Great Britain    10857
# France           10559
# Italy             8575
# Germany           7975
# Australia         7614
# Canada            7198
# Japan             7020
# Hungary           6326
# Sweden            5994
# Name: Team, dtype: int64

# %%
# Plot for the top 10 countries who is participating in the olympics

plt.figure(figsize=(12,6))
#plt.xtricks(rotation=20)
plt.title("Over all Participation by Country")
sns.barplot(x=top_10_countries.index , y=top_10_countries , palette='Set2')
# Out:
# <Axes: title={'center': 'Over all Participation by Country'}, ylabel='Team'>

# %%
# Age distributation of the participants

plt.figure(figsize=(12,6))
plt.title("Age distributation of the athletes")
plt.xlabel('Age')
plt.ylabel('Number Participants')
plt.hist(athletes_df.Age , bins = np.arange(10,80,2) , color = 'green' , edgecolor = 'white');

# %%
winter_sports = athletes_df[athletes_df.Season =='Winter'].Sport.unique()
winter_sports
# Out:
# array([], dtype=object)

# %%
# In the above query we did not get any sports for the winter sports because this Dataset in only for the Athletes_Summer_games

# %%
# Summer olympics
summer_sports = athletes_df[athletes_df.Season =='Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics', 'Cycling Road', 'Artistic Gymnastics',
#        'Karate', 'Baseball/Softball', 'Trampoline Gymnastics',
#        'Marathon Swimming', 'Canoe Slalom', 'Surfing', 'Canoe Sprint',
# ...

# %%
# Male and Female participants
gender_counts = athletes_df.Sex.value_counts()
gender_counts
# Out:
# M    170964
# F     66709
# Name: Sex, dtype: int64

# %%
# pie plot for male and female participants
plt.figure(figsize=(12,6))
plt.title("Gender Distributation")
plt.pie(gender_counts , labels=gender_counts.index, autopct='%1.1f%%', startangle = 150, shadow = True);

# %%
# Total Medals

athletes_df.Medal.value_counts()
# Out:
# Bronze    12276
# Gold      12259
# Silver    12002
# Name: Medal, dtype: int64

# %%
# Total number of female athletes in each olympics.

female_participants = athletes_df[(athletes_df.Sex=='F') & (athletes_df.Season == "Summer")][['Sex','Year']]
female_participants = female_participants.groupby('Year').count().reset_index()
female_participants.head()
# Out:
#    Year  Sex
# 0  1900   33
# 1  1904   16
# 2  1906   11
# 3  1908   47
# 4  1912   87

# %%
# the above result is very old data if we want to see recent data then....

female_participants.tail()
# Out:
#     Year   Sex
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223
# 28  2020  7266

# %%
womenOlympics = athletes_df[(athletes_df.Sex == 'F') & (athletes_df.Season == 'Summer')]
womenOlympics.head()
# Out:
#     ID                                Name Sex   Age         Team  NOC  \
# 4   26  Cornelia "Cor" Aalten (-Strannood)   F  18.0  Netherlands  NED
# 5   27  Cornelia "Cor" Aalten (-Strannood)   F  18.0  Netherlands  NED
# 8   32                  Minna Maarit Aalto   F  30.0      Finland  FIN
# 9   33                  Minna Maarit Aalto   F  34.0      Finland  FIN
# 33  79           Ragnhild Margrethe Aamodt   F  27.0       Norway  NOR
#
#           Games  Year  Season         City      Sport  \
# 4   1932 Summer  1932  Summer  Los Angeles  Athletics
# 5   1932 Summer  1932  Summer  Los Angeles  Athletics
# 8   1996 Summer  1996  Summer      Atlanta    Sailing
# 9   2000 Summer  2000  Summer       Sydney    Sailing
# 33  2008 Summer  2008  Summer      Beijing   Handball
#
#                                      Event Medal  Unnamed: 0       Region  \
# 4             Athletics Women's 100 metres   NaN         149  Netherlands
# ...

# %%
sns.set(style = "darkgrid")
plt.figure(figsize=(12,10))
sns.countplot(x='Year', data=womenOlympics, palette = 'Spectral')
plt.title('Women Participation')
# Out:
# Text(0.5, 1.0, 'Women Participation')

# %%
part = womenOlympics.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(20,10))
part.loc[:,'F'].plot()
plt.title('Plot of Female Athletes over time')
# Out:
# Text(0.5, 1.0, 'Plot of Female Athletes over time')

# %%
# gold medal athletes

goldMedals = athletes_df[(athletes_df.Medal == 'Gold')]
goldMedals.head()
# Out:
#     ID                       Name Sex   Age            Team  NOC        Games  \
# 3    3       Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN  1900 Summer
# 16  42    Paavo Johannes Aaltonen   M  28.0         Finland  FIN  1948 Summer
# 18  44    Paavo Johannes Aaltonen   M  28.0         Finland  FIN  1948 Summer
# 22  48    Paavo Johannes Aaltonen   M  28.0         Finland  FIN  1948 Summer
# 33  79  Ragnhild Margrethe Aamodt   F  27.0          Norway  NOR  2008 Summer
#
#     Year  Season     City       Sport                             Event Medal  \
# 3   1900  Summer    Paris  Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 16  1948  Summer   London  Gymnastics  Gymnastics Men's Team All-Around  Gold
# 18  1948  Summer   London  Gymnastics      Gymnastics Men's Horse Vault  Gold
# 22  1948  Summer   London  Gymnastics  Gymnastics Men's Pommelled Horse  Gold
# 33  2008  Summer  Beijing    Handball         Handball Women's Handball  Gold
#
# ...

# %%
# take only the values that are different from NaN.

goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]
goldMedals
# Out:
#            ID                       Name Sex   Age            Team  NOC  \
# 3           3       Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 16         42    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 18         44    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 22         48    Paavo Johannes Aaltonen   M  28.0         Finland  FIN
# 33         79  Ragnhild Margrethe Aamodt   F  27.0          Norway  NOR
# ...       ...                        ...  ..   ...             ...  ...
# 237600  15048              ZHONG Tianshi   F  30.0           China  CHN
# 237613  15061                ZHU Xueying   F  23.0           China  CHN
# 237643  15091         ZOLOTIC Anastasija   F  18.0   United States  USA
# 237652  15100               ZOU Jingyuan   M  23.0           China  CHN
# 237664  15112           ZVEREV Alexander   M  24.0         Germany  GER
#
#               Games  Year  Season     City                  Sport  \
# ...

# %%
# Gold beyond 60

goldMedals['ID'][goldMedals['Age'] > 60].count()
# Out:
# 6

# %%
sporting_event = goldMedals['Sport'][goldMedals['Age']>60]
sporting_event
# Out:
# 85970     Art Competitions
# 86948                Roque
# 157206             Archery
# 185948             Archery
# 191460            Shooting
# 214409             Archery
# Name: Sport, dtype: object

# %%
# Gold Medals from each country

goldMedals.Region.value_counts().reset_index(name='Medal').head(5)
# Out:
#      index  Medal
# 0      USA   2574
# 1   Russia   1261
# 2  Germany   1088
# 3       UK    657
# 4    Italy    532

# %%
# Plot for above table

totalGoldMedals = goldMedals.Region.value_counts().reset_index(name='Medal').head(6)
g = sns.catplot(x = 'index', y = 'Medal', data = totalGoldMedals, height=5, kind="bar", palette='rocket')
g.despine(left = True)
g.set_xlabels("Top 5 Countries")
g.set_ylabels("Number of Medals")
plt.title("Gold Medals per Country")
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
#Total Gold Medals for top 10 countries in 2020 Summer Olympics 

max_year = athletes_df.Year.max()
print(max_year)

team_name = athletes_df[(athletes_df.Year == max_year) & (athletes_df.Medal =='Gold')].Team
team_name.value_counts().head(10)
# Out:
# 2020
# United States    113
# Japan             68
# France            65
# China             59
# Great Britain     41
# Russia            41
# Australia         36
# Canada            36
# Netherlands       33
# New Zealand       29
# Name: Team, dtype: int64

# %%
# Using the above table we are going to plot the barchart

sns.barplot(x=team_name.value_counts().head(20), y=team_name.value_counts().head(20).index)
plt.ylabel(None)
plt.xlabel('Countrywise Medals for for the Year 2020')
# Out:
# Text(0.5, 0, 'Countrywise Medals for for the Year 2020')
